# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as pp

# %%
#Attenuation data import and plot
header2=['Energy','Trans']

#At 90 degree:

#Al 2.699 g/cm^3 
Al2Xraydata = pd.read_csv('Al2mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Al2df=Al2Xraydata.set_index('Energy')
Al2df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:7: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#            Trans
# Energy
# 30.0    0.410287
# 35.0    0.412798
# 40.0    0.429501
# 45.0    0.458375
# 50.0    0.522605

# %%
#Cu 8.96 g/cm^3 
Cu8Xraydata = pd.read_csv('Cu8mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Cu8df=Cu8Xraydata.set_index('Energy')
Cu8df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#            Trans
# Energy
# 30.0    0.010452
# 35.0    0.012225
# 40.0    0.014268
# 45.0    0.014556
# 50.0    0.014722

# %%
#Co 8.9 g/cm^3 
Co8Xraydata = pd.read_csv('Co8mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Co8df=Co8Xraydata.set_index('Energy')
Co8df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#            Trans
# Energy
# 30.0    0.010862
# 35.0    0.013033
# 40.0    0.015472
# 45.0    0.017841
# 50.0    0.020245

# %%
#Fe 7.874 g/cm^3 
Fe7Xraydata = pd.read_csv('Fe19mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Fe7df=Fe7Xraydata.set_index('Energy')
Fe7df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#            Trans
# Energy
# 30.0    0.015708
# 35.0    0.019365
# 40.0    0.023394
# 45.0    0.028188
# 50.0    0.033480

# %%
#Pb 11 g/cm^3 
Pb11Xraydata = pd.read_csv('Pb11mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Pb11df=Pb11Xraydata.set_index('Energy')
Pb11df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#            Trans
# Energy
# 30.0    0.021941
# 35.0    0.017267
# 40.0    0.014179
# 45.0    0.012547
# 50.0    0.011886

# %%
#Au 19.32 g/cm^3 
Au19Xraydata = pd.read_csv('Au19mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
Au19df=Au19Xraydata.set_index('Energy')
Au19df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
#            Trans
# Energy
# 30.0    0.005984
# 35.0    0.006862
# 40.0    0.007783
# 45.0    0.008457
# 50.0    0.009586

# %%
#W 19.3 g/cm^3 
W19Xraydata = pd.read_csv('W19mu90AttRatexray302020step400.txt',names=header2, sep='  ',skiprows=2);
W19df=W19Xraydata.set_index('Energy')
W19df.head()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   app.launch_new_instance()
#            Trans
# Energy
# 30.0    0.016065
# 35.0    0.020694
# 40.0    0.009790
# 45.0    0.009792
# 50.0    0.007355

# %%
W19,=plt.plot(W19Xraydata['Energy'],W19Xraydata['Trans'], color='k',label=' $W^{74}$ 19.3$g/cm^3$')
Au19,=plt.plot(Au19Xraydata['Energy'],Au19Xraydata['Trans'], color='r',label='$Au^{79}$ 19.32 $g/cm^3$')
Pb11,=plt.plot(Pb11Xraydata['Energy'],Pb11Xraydata['Trans'], color='b',label='$Pb^{82}$ 11.35 $g/cm^3$')
#Fe7,=plt.plot(Fe7Xraydata['Energy'],Fe7Xraydata['Trans'], color='gold',label='$Fe^{26}$ 7.874 $g/cm^3$')
#Co8,=plt.plot(Co8Xraydata['Energy'],Co8Xraydata['Trans'], color='green',label='$Co^{27}$ 8.9 $g/cm^3$')
#Cu8,=plt.plot(Cu8Xraydata['Energy'],Cu8Xraydata['Trans'], color='gold',label='$Cu^{29}$ 8.96 $g/cm^3$')
#Fe7,=plt.plot(Fe7Xraydata['Energy'],Fe7Xraydata['Trans'], color='gold',label='$Fe^{26}$ 7.874 $g/cm^3$')
#Al2,=plt.plot(Al2Xraydata['Energy'],Al2Xraydata['Trans'], color='orange',label='$Al^{13}$ 2.699 $g/cm^3$')


plt.xlabel('Energy')
plt.ylabel('Attenuation Length $\mu m$')
plt.title(r'X-Ray Attenuation Length')
plt.legend()

plt.savefig('compare302030ev.pdf',dpi=300)
plt.savefig('compare302030ev.png',dpi=300)

plt.show()

# %%
headers = ['Energy', 'Flux', 'PL', 'PC', 'PL45', '1-|PL|'];
#data3 = pd.read_csv('data6.csv',names=headers,sep=' ');

data3 = pd.read_csv('calculation_SM_TFluxenergy.txt',names=headers, sep='  ',skiprows=10);
data3.tail()
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/ipykernel/__main__.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#       Energy          Flux        PL   PC  PL45    1-|PL|
# 1896  1996.0  7.818000e+14  0.717673  0.0   0.0  0.282326
# 1897  1997.0  7.828000e+14  0.718266  0.0   0.0  0.281734
# 1898  1998.0  7.840000e+14  0.718900  0.0   0.0  0.281100
# 1899  1999.0  7.854000e+14  0.719564  0.0   0.0  0.280436
# 1900  2000.0  7.871000e+14  0.720238  0.0   0.0  0.279762

# %%
data3=data3.set_index('Energy')

# %%
data3.head()
# Out:
#                 Flux        PL   PC  PL45    1-|PL|
# Energy
# 100.0   4.541000e+14  0.341260  0.0   0.0  0.658740
# 101.0   4.613000e+14  0.349941  0.0   0.0  0.650059
# 102.0   4.685000e+14  0.358391  0.0   0.0  0.641609
# 103.0   4.757000e+14  0.366648  0.0   0.0  0.633352
# 104.0   4.831000e+14  0.375001  0.0   0.0  0.624999

# %%
Flux_data=data3.loc[100:2030];

# %%
Flux_data.head()
# Out:
#                 Flux        PL   PC  PL45    1-|PL|
# Energy
# 100.0   4.541000e+14  0.341260  0.0   0.0  0.658740
# 101.0   4.613000e+14  0.349941  0.0   0.0  0.650059
# 102.0   4.685000e+14  0.358391  0.0   0.0  0.641609
# 103.0   4.757000e+14  0.366648  0.0   0.0  0.633352
# 104.0   4.831000e+14  0.375001  0.0   0.0  0.624999

# %%
Flux_data.tail()
# Out:
#                 Flux        PL   PC  PL45    1-|PL|
# Energy
# 1996.0  7.818000e+14  0.717673  0.0   0.0  0.282326
# 1997.0  7.828000e+14  0.718266  0.0   0.0  0.281734
# 1998.0  7.840000e+14  0.718900  0.0   0.0  0.281100
# 1999.0  7.854000e+14  0.719564  0.0   0.0  0.280436
# 2000.0  7.871000e+14  0.720238  0.0   0.0  0.279762

# %%
Au19Xraydata=Au19Xraydata.set_index('Energy')

# %%
Au19Att=Au19Xraydata.loc[100:2000]
Au19Att.head()
# Out:
#            Trans
# Energy
# 100.0   0.028035
# 105.0   0.033215
# 110.0   0.038728
# 115.0   0.043995
# 120.0   0.049461

# %%
W19Xraydata=W19Xraydata.set_index('Energy')
W19Att=W19Xraydata.loc[100:2000]
W19Att.head()
# Out:
#            Trans
# Energy
# 100.0   0.032188
# 105.0   0.031691
# 110.0   0.031200
# 115.0   0.030540
# 120.0   0.029905

# %%
Flux_data=data3.loc[100:2000:5];
#Flux_data=Flux_data['Flux']
Flux_data.head()
# Out:
#                 Flux        PL   PC  PL45    1-|PL|
# Energy
# 100.0   4.541000e+14  0.341260  0.0   0.0  0.658740
# 105.0   4.906000e+14  0.383373  0.0   0.0  0.616627
# 110.0   5.292000e+14  0.423037  0.0   0.0  0.576963
# 115.0   5.697000e+14  0.458138  0.0   0.0  0.541862
# 120.0   6.084000e+14  0.487972  0.0   0.0  0.512028

# %%
FluxtimeAttW19=W19Att['Trans']*Flux_data['Flux']

# %%
FluxtimeAttAu19=Au19Att['Trans']*Flux_data['Flux']
FluxtimeAttAu19.head()
# Out:
# Energy
# 100.0    1.273063e+13
# 105.0    1.629512e+13
# 110.0    2.049465e+13
# 115.0    2.506417e+13
# 120.0    3.009210e+13
# dtype: float64

# %%
fAu19,=plt.plot(FluxtimeAttAu19.index,FluxtimeAttAu19, color='k',label='$Au^{79}$ 19.32 $g/cm^3$')
fW19,=plt.plot(FluxtimeAttW19.index,FluxtimeAttW19, color='b',label='$W^{74}$ 19.3$g/cm^3$')

plt.xlabel('Energy')
plt.ylabel('Attenuation Length $\mu m$ times Brilliance')
plt.title(r'X-Ray Attenuated Brilliance vs. Energy')
plt.legend()

plt.savefig('AttenuatedPhotons.pdf',dpi=300)
plt.savefig('AttenuatedPhotons.png',dpi=300)

plt.show()
